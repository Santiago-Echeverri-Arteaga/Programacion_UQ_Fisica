# %%
import os
print(os.path.realpath("COVID.csv"))
print(os.path.join(os.getcwd(),"Hola_mundo"))
# Out:
# /Users/itnas/Documents/UQ/Programacion/2023-1/Repositorio/Codigos/COVID.csv
# /Users/itnas/Documents/UQ/Programacion/2023-1/Repositorio/Codigos/Hola_mundo

# %% [markdown]
# # Importando con Python modules

# %%
text = open('odisea.txt').read()
text = text.lower()
print(f"Longitud: {len(text)}\nTipo de dato: {type(text)}")
# Out:
# Longitud: 858525
# Tipo de dato: <class 'str'>

# %% [markdown]
# # Importando archivos usando &#128060;

# %%
#!pip install pandas
import pandas as pd
data = pd.read_csv("COVID19.csv")
data.head()
# Out:
# /var/folders/pb/ldktvl7n1cjb78yx2vbmbmdr0000gn/T/ipykernel_1098/3304175893.py:3: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("COVID19.csv")
#    fecha reporte web  ID de caso Fecha de notificación  \
# 0   6/3/2020 0:00:00           1      2/3/2020 0:00:00
# 1   9/3/2020 0:00:00           2      6/3/2020 0:00:00
# 2   9/3/2020 0:00:00           3      7/3/2020 0:00:00
# 3  11/3/2020 0:00:00           4      9/3/2020 0:00:00
# 4  11/3/2020 0:00:00           5      9/3/2020 0:00:00
#
#    Código DIVIPOLA departamento Nombre departamento  \
# 0                            11              BOGOTA
# 1                            76               VALLE
# 2                             5           ANTIOQUIA
# 3                             5           ANTIOQUIA
# 4                             5           ANTIOQUIA
#
#    Código DIVIPOLA municipio Nombre municipio  Edad  Unidad de medida de edad  \
# ...

# %%
display(data.tail(20))
# Out:
#          fecha reporte web  ID de caso Fecha de notificación  \
# 5003957  1/11/2021 0:00:00     5003998     13/6/2021 0:00:00
# 5003958  1/11/2021 0:00:00     5003999      5/6/2021 0:00:00
# 5003959  1/11/2021 0:00:00     5004000     29/5/2021 0:00:00
# 5003960  1/11/2021 0:00:00     5004001     12/2/2021 0:00:00
# 5003961  1/11/2021 0:00:00     5004002     12/2/2021 0:00:00
# 5003962  1/11/2021 0:00:00     5004003     11/2/2021 0:00:00
# 5003963  1/11/2021 0:00:00     5004004      9/2/2021 0:00:00
# 5003964  1/11/2021 0:00:00     5004005      7/2/2021 0:00:00
# 5003965  1/11/2021 0:00:00     5004006      4/2/2021 0:00:00
# 5003966  1/11/2021 0:00:00     5004007      3/2/2021 0:00:00
# 5003967  1/11/2021 0:00:00     5004008      1/2/2021 0:00:00
# 5003968  1/11/2021 0:00:00     5004009      1/2/2021 0:00:00
# 5003969  1/11/2021 0:00:00     5004010     30/1/2021 0:00:00
# 5003970  1/11/2021 0:00:00     5004011     27/1/2021 0:00:00
# ...

# %%
data[[data.columns[4],data.columns[5]]]
# Out:
#         Nombre departamento  Código DIVIPOLA municipio
# 0                    BOGOTA                      11001
# 1                     VALLE                      76111
# 2                 ANTIOQUIA                       5001
# 3                 ANTIOQUIA                       5001
# 4                 ANTIOQUIA                       5001
# ...                     ...                        ...
# 5003972             CORDOBA                      23001
# 5003973             CORDOBA                      23001
# 5003974             CORDOBA                      23001
# 5003975             CORDOBA                      23001
# 5003976             CORDOBA                      23001
#
# [5003977 rows x 2 columns]

# %%
data[data.columns[4]]=data[data.columns[4]].replace("Caldas","CALDAS")
pd.unique(data[data.columns[4]])
# Out:
# array(['BOGOTA', 'VALLE', 'ANTIOQUIA', 'CARTAGENA', 'HUILA', 'META',
#        'RISARALDA', 'NORTE SANTANDER', 'CALDAS', 'CUNDINAMARCA',
#        'BARRANQUILLA', 'SANTANDER', 'QUINDIO', 'TOLIMA', 'CAUCA',
#        'STA MARTA D.E.', 'CESAR', 'SAN ANDRES', 'CASANARE', 'NARIÑO',
#        'ATLANTICO', 'BOYACA', 'CORDOBA', 'BOLIVAR', 'SUCRE', 'MAGDALENA',
#        'GUAJIRA', 'CHOCO', 'AMAZONAS', 'CAQUETA', 'PUTUMAYO', 'ARAUCA',
#        'VAUPES', 'GUAINIA', 'VICHADA', 'GUAVIARE', 'Tolima'], dtype=object)

# %%
DPTOS = pd.unique(data[data.columns[4]])
DPTOS.sort()
DPTOS
# Out:
# array(['AMAZONAS', 'ANTIOQUIA', 'ARAUCA', 'ATLANTICO', 'BARRANQUILLA',
#        'BOGOTA', 'BOLIVAR', 'BOYACA', 'CALDAS', 'CAQUETA', 'CARTAGENA',
#        'CASANARE', 'CAUCA', 'CESAR', 'CHOCO', 'CORDOBA', 'CUNDINAMARCA',
#        'Caldas', 'GUAINIA', 'GUAJIRA', 'GUAVIARE', 'HUILA', 'MAGDALENA',
#        'META', 'NARIÑO', 'NORTE SANTANDER', 'PUTUMAYO', 'QUINDIO',
#        'RISARALDA', 'SAN ANDRES', 'SANTANDER', 'STA MARTA D.E.', 'SUCRE',
#        'TOLIMA', 'Tolima', 'VALLE', 'VAUPES', 'VICHADA'], dtype=object)

# %%
ocurrencias = data[data.columns[4]].value_counts()
ocurrencias["BOGOTA"]
# Out:
# 1455250

# %%
data.info(null_counts=True)
# Out:
# /var/folders/pb/ldktvl7n1cjb78yx2vbmbmdr0000gn/T/ipykernel_1008/2063078779.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   data.info(null_counts=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5003977 entries, 0 to 5003976
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   fecha reporte web             5003977 non-null  object
#  1   ID de caso                    5003977 non-null  int64
#  2   Fecha de notificación         5003977 non-null  object
#  3   Código DIVIPOLA departamento  5003977 non-null  int64
#  4   Nombre departamento           5003977 non-null  object
#  5   Código DIVIPOLA municipio     5003977 non-null  int64
#  6   Nombre municipio              5003977 non-null  object
#  7   Edad                          5003977 non-null  int64
#  8   Unidad de medida de edad      5003977 non-null  int64
# ...

# %%
data.describe()
# Out:
#          ID de caso  Código DIVIPOLA departamento  Código DIVIPOLA municipio  \
# count  5.003977e+06                  5.003977e+06               5.003977e+06
# mean   2.502029e+06                  1.327586e+03               2.827735e+04
# std    1.444524e+06                  5.942108e+03               2.610482e+04
# min    1.000000e+00                  5.000000e+00               5.001000e+03
# 25%    1.251035e+06                  1.100000e+01               1.100100e+04
# 50%    2.502029e+06                  1.700000e+01               1.100100e+04
# 75%    3.753023e+06                  6.800000e+01               5.000600e+04
# max    5.004017e+06                  4.700100e+04               9.977300e+04
#
#                Edad  Unidad de medida de edad  Código ISO del país  \
# count  5.003977e+06              5.003977e+06          3140.000000
# mean   3.950413e+01              1.003588e+00           594.338854
# std    1.795638e+01              6.500582e-02           287.720892
# ...

# %%
data = data.fillna(value = {"Nombre del país": "N/A"})
data.info(null_counts=True)
# Out:
# /var/folders/pb/ldktvl7n1cjb78yx2vbmbmdr0000gn/T/ipykernel_1098/949642919.py:2: FutureWarning: null_counts is deprecated. Use show_counts instead
#   data.info(null_counts=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5003977 entries, 0 to 5003976
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   fecha reporte web             5003977 non-null  object
#  1   ID de caso                    5003977 non-null  int64
#  2   Fecha de notificación         5003977 non-null  object
#  3   Código DIVIPOLA departamento  5003977 non-null  int64
#  4   Nombre departamento           5003977 non-null  object
#  5   Código DIVIPOLA municipio     5003977 non-null  int64
#  6   Nombre municipio              5003977 non-null  object
#  7   Edad                          5003977 non-null  int64
#  8   Unidad de medida de edad      5003977 non-null  int64
# ...

# %%
data[["Nombre del país","Edad"]].to_numpy()
# Out:
# array([['ITALIA', 19],
#        ['ESPAÑA', 34],
#        ['ESPAÑA', 50],
#        ...,
#        [nan, 22],
#        [nan, 54],
#        [nan, 63]], dtype=object)

# %%
energy = pd.read_csv("Energy_data_1990_2020.csv")
energy.head()
# Out:
#    country  Year       Region  CO2 emissions from fuel combustion (MtCO2)  \
# 0  Algeria  1990  Arab States                                   52.981921
# 1  Algeria  1991  Arab States                                   57.149971
# 2  Algeria  1992  Arab States                                   57.262430
# 3  Algeria  1993  Arab States                                   59.198702
# 4  Algeria  1994  Arab States                                   56.347927
#
#    Average CO2 emission factor (tCO2/toe)  \
# 0                                2.387855
# 1                                2.435026
# 2                                2.383517
# 3                                2.455335
# 4                                2.424649
#
#    CO2 intensity at constant purchasing power parities (kCO2/$15p)  \
# 0                                           0.228889
# 1                                           0.249895
# 2                                           0.245959
# ...

# %%
energy.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1364 entries, 0 to 1363
# Data columns (total 21 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   country                                                                   1364 non-null   object
#  1   Year                                                                      1364 non-null   int64
#  2   Region                                                                    1364 non-null   object
#  3   CO2 emissions from fuel combustion (MtCO2)                                1364 non-null   float64
#  4   Average CO2 emission factor (tCO2/toe)                                    1364 non-null   float64
#  5   CO2 intensity at constant purchasing power parities (kCO2/$15p)           1364 non-null   float64
# ...

# %%
columnas_energy = ["Average CO2 emission factor (tCO2/toe)","CO2 emissions from fuel combustion (MtCO2)"]
energy_selected = energy[columnas_energy].to_numpy()
print(energy_selected)
# Out:
# [[  2.38785534  52.9819211 ]
#  [  2.43502645  57.14997082]
#  [  2.38351699  57.26243   ]
#  ...
#  [  2.70164625 113.2495533 ]
#  [  2.79362372 101.2002058 ]
#  [  2.91647834  85.04835596]]

# %% [markdown]
# # Ahora aprendemos a usar Numpy para procesarlos

# %% [markdown]
# # Y finalmente aprendemos a usar Matplotlib para graficarlos
